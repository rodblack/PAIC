# %%
import os
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np
from cartopy.util import add_cyclic_point

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/xarray/backends/file_manager.py in acquire(self)
#     136             try:
# --> 137                 file = self._cache[self._key]
#     138             except KeyError:
#
# ~/anaconda3/lib/python3.6/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      42         with self._lock:
# ---> 43             value = self._cache[key]
#      44             move_to_end(self._cache, key)
#
# KeyError: [<function _open_scipy_netcdf at 0x7f43dcd600d0>, ('/home/aluno/RodProj/dados/precip_observado/precip.mon.mean.nc',), 'r', (('mmap', None), ('version', 2))]
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ...

# %%
variaveis = ['prate', '2t']

path = "../anomalias/CMC1"
caminho = '../graf/CMC1/prate/tempo1/'

arquivos = sorted(os.listdir(path))

#Contador para cada arquivo lido
#Variáveis para cada mês e variável da média
cont = 0
var1 = 0
var2 = 0
var3 = 0
var = 0

for name in arquivos:
    if name.endswith(".nc"):
        
        
        cont = cont + 1
        
        file = xr.open_dataset(os.path.join(path, name), decode_times=True)
        
        lat = file['lat']
        lon = file['lon']
        
        for a in file.data_vars:
            if a in variaveis:
                var1 = (file[a][0,:,:]).squeeze()
                #var2 = (file[a][1,:,:]).squeeze()
                #var3 = (file[a][2,:,:]).squeeze()
                
                #cvarObservado
                
        
                #var = var + ((var1+var2+var3)/3)
            

        #var = var/cont
        
        #var2 = var1/cont

        cvar1, clon = add_cyclic_point(var1.values, coord=lon, axis=1)
        #cvar2, clon = add_cyclic_point(var2.values, coord=lon, axis=1)
        #cvar3, clon = add_cyclic_point(var3.values, coord=lon, axis=1)

        #((((cvar1.squeeze()+cvar2.squeeze()+cvar3.squeeze())/3)*60*60*24))/cont

        if a == 'prate':
            fig = plt.figure(figsize=(15,10))

            ax = fig.add_subplot(111, projection=ccrs.PlateCarree())

            contour = ax.contourf(clon, lat, (cvar1.squeeze()*60*60*24), levels = np.arange(-10,10,1),
                                  transform=ccrs.PlateCarree(),cmap = plt.get_cmap('BrBG'), extend='both')

        elif a == '2t':
            fig = plt.figure(figsize=(15,10))

            ax = fig.add_subplot(111, projection=ccrs.PlateCarree())

            contour = ax.contourf(clon, lat, cvar, levels = np.arange(-10,10,1),
                                  transform=ccrs.PlateCarree(),cmap = plt.get_cmap('RdBu_r'), extend='both')



        fig.colorbar(contour, shrink = 0.6, orientation = 'vertical')

        ax.add_feature(cfeature.BORDERS)
        ax.add_feature(cfeature.COASTLINE)


        if not os.path.exists(caminho):
            os.makedirs(caminho)

        fig.savefig(caminho+name[:-3]+'.png', dpi=300)
        plt.close('all')
